# %%
import cv2 as cv
import os
from matplotlib import pyplot as plt
import numpy as np
SAMPLE9_PATH = '/home/ning_a/Desktop/CAPTCHA/dark_web_captcha/rescator_me/296.png'

# %%
def Gray2Blur(source_path, target_path):
    img_sources = os.listdir(source_path)
    for eachimg in img_sources:
        print(source_path+eachimg)
Gray2Blur('/home/ning_a/Desktop/CAPTCHA/dataset_1.1/train/0/','')
# Out:
# /home/ning_a/Desktop/CAPTCHA/dataset_1.1/train/0/890.png
# /home/ning_a/Desktop/CAPTCHA/dataset_1.1/train/0/900.png
# /home/ning_a/Desktop/CAPTCHA/dataset_1.1/train/0/1836.png
# /home/ning_a/Desktop/CAPTCHA/dataset_1.1/train/0/1904.png
# /home/ning_a/Desktop/CAPTCHA/dataset_1.1/train/0/940.png
# /home/ning_a/Desktop/CAPTCHA/dataset_1.1/train/0/245.png
# /home/ning_a/Desktop/CAPTCHA/dataset_1.1/train/0/1998.png
# /home/ning_a/Desktop/CAPTCHA/dataset_1.1/train/0/1732.png
# /home/ning_a/Desktop/CAPTCHA/dataset_1.1/train/0/2181.png
# /home/ning_a/Desktop/CAPTCHA/dataset_1.1/train/0/696.png
# /home/ning_a/Desktop/CAPTCHA/dataset_1.1/train/0/1742.png
# /home/ning_a/Desktop/CAPTCHA/dataset_1.1/train/0/1892.png
# /home/ning_a/Desktop/CAPTCHA/dataset_1.1/train/0/585.png
# /home/ning_a/Desktop/CAPTCHA/dataset_1.1/train/0/1342.png
# /home/ning_a/Desktop/CAPTCHA/dataset_1.1/train/0/247.png
# /home/ning_a/Desktop/CAPTCHA/dataset_1.1/train/0/1036.png
# ...

# %%
def
